# %%
import pandas
import pandas as pd
import geopandas as gpd
import folium
import matplotlib.pyplot as plt

# %%
#neccessary libraries to be installed
'''
# %pip install folium
# %pip install geopandas
# %pip install matplotlib
# %pip install folium matplotlib mapclassify
'''
# Out:
# '\n%pip install folium\n%pip install geopandas\n%pip install matplotlib\n%pip install folium matplotlib mapclassify\n'

# %% [markdown]
# If you consider Toronto to be defined by its city wards, the centre of Toronto lies at 43.725518°N, 79.390531°W.
#
# If you consider Toronto to be defined by its neighbourhoods, the centre of Toronto lies at 43.726495°N, 79.390641°W.
#
# https://glaikit.org/2010/03/06/finding-the-exact-geographic-centre-of-toronto/

# %%
#including GTA 
toronto_lat_long_tup = (43.725518, -79.390531)

# %%
toronto_base_map = folium.Map(location=toronto_lat_long_tup, zoom_start=12, tiles='Stamen Terrain')

# %%
toronto_base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
gdf = gpd.read_file('Red Light Cameras Data - 4326.geojson')
gdf.head()
# Out:
#    _id  INTERSECTION_ID LINEAR_NAME_FULL_1 LINEAR_NAME_FULL_2  MI_PRINX  \
# 0    1       13465959.0      Richmond St E      Parliament St         1
# 1    2       13467993.0  Lake Shore Blvd W            York St         2
# 2    3       13444656.0      Steeles Ave W       Carpenter Rd         3
# 3    4       13444138.0      Steeles Ave W          Hilda Ave         4
# 4    5       13451893.0          Albion Rd     Silverstone Dr         5
#
#    OBJECTID  ID    CLIENT_STREET_1 CLIENT_STREET_2   RLC  ...  \
# 0         1   1      RICHMOND ST E   PARLIAMENT ST  6001  ...
# 1         2   2  LAKE SHORE BLVD W         YORK ST  6002  ...
# 2         3   3      STEELES AVE W    CARPENTER RD  6003  ...
# 3         4   4      STEELES AVE W       HILDA AVE  6004  ...
# 4         5   5          ALBION RD  SILVERSTONE DR  6005  ...
#
#                 DISTRICT                 WARD_1 WARD_2 WARD_3 WARD_4  \
# 0  Toronto and East York     Toronto Centre(13)   None   None   None
# ...

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   _id                 289 non-null    int64
#  1   INTERSECTION_ID     278 non-null    float64
#  2   LINEAR_NAME_FULL_1  289 non-null    object
#  3   LINEAR_NAME_FULL_2  289 non-null    object
#  4   MI_PRINX            289 non-null    int64
#  5   OBJECTID            289 non-null    int64
#  6   ID                  289 non-null    int64
#  7   CLIENT_STREET_1     289 non-null    object
#  8   CLIENT_STREET_2     289 non-null    object
#  9   RLC                 289 non-null    int64
#  10  TCS                 289 non-null    int64
#  11  NAME                289 non-null    object
#  12  ADDITIONAL_INFO     289 non-null    object
#  13  MAIN                289 non-null    object
#  14  SIDE1               289 non-null    object
# ...

# %%
# to handle following error
'''
TypeError: Object of type 'Timestamp' is not JSON serializable'
'''

gdf['ACTIVATION_DATE'] = gdf['ACTIVATION_DATE'].astype(str)

# %%
redLightCameraMap = gdf.explore(column='NAME', name='Area Name')
folium.LayerControl().add_to(redLightCameraMap)
toronto_base_map.add_to(redLightCameraMap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
toronto_base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#save_file

redLightCameraMap.save("red_light_camera_data.html")

# %%
toronto_boundaries_gdf = gpd.read_file('toronto_crs84.geojson')

# %%
toronto_boundaries_gdf.head()
# Out:
#   AREA_S_CD                     AREA_NAME  \
# 0       097           Yonge-St.Clair (97)
# 1       027  York University Heights (27)
# 2       038         Lansing-Westgate (38)
# 3       031       Yorkdale-Glen Park (31)
# 4       016      Stonegate-Queensway (16)
#
#                                             geometry
# 0  POLYGON ((-79.39119 43.68108, -79.39141 43.680...
# 1  POLYGON ((-79.50529 43.75987, -79.50488 43.759...
# 2  POLYGON ((-79.43998 43.76156, -79.44004 43.761...
# 3  POLYGON ((-79.43969 43.70561, -79.44011 43.705...
# 4  POLYGON ((-79.49262 43.64744, -79.49277 43.647...
